# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.listdir("/content/drive/MyDrive")
# Out:
# ['Colab Notebooks',
#  'Getting started.pdf',
#  'Book1.csv',
#  'AlzheimersData.csv',
#  'Churn_Modelling.csv',
#  'customers-1000.csv',
#  'Daisi_Williams_Academic_grades.pdf',
#  'Daisi_Williams_Curriculum_Vitae.pdf',
#  '6439.jpg',
#  'send_Williams.zip',
#  'UIQC Membership Form – DAISI WILLIAMS.gdoc',
#  '2025-10',
#  'Vids Exports',
#  'Untitled video (3).gvid',
#  'Untitled video (2).gvid',
#  'Untitled video (1).gvid',
#  'Untitled video.gvid',
#  'Daisi Williams_Hackathon_Solution.pdf',
#  'explorer_KxO7TN12bp.mp4',
#  'merged_with_CM_5dp.csv',
#  'samplequestions.pdf',
#  'Experimental Lab 4 - Waldron.docx',
#  'Daisi Williams SOP.pdf',
#  'Determination_of_Plancks_Constant_by_Measurement_of_the_Photoelectric_Effect.pdf',
#  'Personal Statement MSE.gdoc',
#  'Personal Statement Physics.gdoc',
#  'SOP phyiscs.gdoc',
#  'SOP MSE.gdoc',
#  'weather_cnn_rnn_model.h5',
#  'class_names.json',
#  'cleaned_merged_with_CM_5dp.csv']

# %%
import pandas as pd
import numpy as np

CSV_PATH = "/content/drive/MyDrive/merged_with_CM_5dp.csv"
df = pd.read_csv(CSV_PATH)

bad_rows = [4654, 21291]   # <-- pandas row indices (0-based)

df_clean = df.drop(index=bad_rows).reset_index(drop=True)

print("Original rows:", len(df))
print("Cleaned rows :", len(df_clean))
print("Dropped rows :", bad_rows)
# Out:
# Original rows: 21323
# Cleaned rows : 21321
# Dropped rows : [4654, 21291]

# %%
baseline_E1 = df_clean["E1-DFTB"].to_numpy(dtype=float)

print("E1-DFTB range after cleaning:",
      baseline_E1.min(), baseline_E1.max())

# Optional: confirm no huge outliers remain
print("Count E1-DFTB > 10:", np.sum(baseline_E1 > 10))
# Out:
# E1-DFTB range after cleaning: 0.0004 21011.0
# Count E1-DFTB > 10: 25

# %%
# Rows with suspiciously large values
mask_large = df_clean["E1-DFTB"] >= 2.0

# Rows with near-zero values
mask_small = df_clean["E1-DFTB"] < 0.01

print("Count E1-DFTB >= 2.0:", mask_large.sum())
print("Count E1-DFTB < 0.01:", mask_small.sum())

df_clean.loc[mask_large | mask_small,
             ["gdb9_index", "E1-DFTB", "E1-CC2"]].head(10)
# Out:
# Count E1-DFTB >= 2.0: 25
# Count E1-DFTB < 0.01: 4
#       gdb9_index  E1-DFTB   E1-CC2
# 201          207    207.0  0.21334
# 1381        1421   1421.0  0.16026
# 1434        1474   1474.0  0.23437
# 1980        2036   2036.0  0.27893
# 2375        2434   2434.0  0.25141
# 2503        2564   2564.0  0.16484
# 2572        2633   2633.0  0.21365
# 3178        3239   3239.0  0.30893
# 3333        3394   3394.0  0.16587
# 3934        4012   4012.0  0.22477

# %%
mask_physical = (
    (df_clean["E1-DFTB"] >= 0.01) &
    (df_clean["E1-DFTB"] <= 2.0)
)

df_phys = df_clean.loc[mask_physical].reset_index(drop=True)

print("Rows before:", len(df_clean))
print("Rows after :", len(df_phys))
print("Dropped    :", len(df_clean) - len(df_phys))
# Out:
# Rows before: 21321
# Rows after : 21292
# Dropped    : 29

# %%
baseline_E1 = df_phys["E1-DFTB"].to_numpy(dtype=float)

print("E1-DFTB range after filtering:",
      baseline_E1.min(), baseline_E1.max())

print("Count E1-DFTB > 2.0:", (baseline_E1 > 2.0).sum())
print("Count E1-DFTB < 0.01:", (baseline_E1 < 0.01).sum())
# Out:
# E1-DFTB range after filtering: 0.01352 0.84876
# Count E1-DFTB > 2.0: 0
# Count E1-DFTB < 0.01: 0

# %%
cm_cols = [c for c in df_phys.columns if c.startswith("CM_")]

X = df_phys[cm_cols].to_numpy(dtype=float)
baseline_E1 = df_phys["E1-DFTB"].to_numpy(dtype=float)
target_E1   = df_phys["E1-CC2"].to_numpy(dtype=float)

dE1 = target_E1 - baseline_E1

print("X shape:", X.shape)
print("ΔE1 range:", dE1.min(), dE1.max())
print("ΔE1 mean ± std:", dE1.mean(), dE1.std())

assert np.isfinite(X).all()
assert np.isfinite(dE1).all()
# Out:
# X shape: (21292, 26)
# ΔE1 range: -0.62257 0.30557999999999996
# ΔE1 mean ± std: -0.015456138925417997 0.09605581848452671

# %%
import numpy as np
import pandas as pd

print("===== DATASET SANITY CHECK =====")

# -----------------------------
# 1. Shape & basic integrity
# -----------------------------
print("\n[1] Dataset shape")
print("Rows:", len(df_phys))
print("Columns:", df_phys.shape[1])

# -----------------------------
# 2. Required columns present
# -----------------------------
required_cols = ["E1-DFTB", "E1-CC2"]
cm_cols = [c for c in df_phys.columns if c.startswith("CM_")]

print("\n[2] Required columns check")
print("E1-DFTB present:", "E1-DFTB" in df_phys.columns)
print("E1-CC2 present :", "E1-CC2" in df_phys.columns)
print("Number of CM features:", len(cm_cols))

# -----------------------------
# 3. No NaN / Inf anywhere
# -----------------------------
print("\n[3] NaN / Inf check")
print("NaNs total:", df_phys.isna().sum().sum())
print("Infs total:",
      np.isinf(df_phys.select_dtypes(include=[float])).sum().sum())

# -----------------------------
# 4. Physical ranges (energies)
# -----------------------------
print("\n[4] Physical range check (Hartree)")
print("E1-DFTB range:",
      df_phys["E1-DFTB"].min(),
      df_phys["E1-DFTB"].max())

print("E1-CC2 range:",
      df_phys["E1-CC2"].min(),
      df_phys["E1-CC2"].max())

# -----------------------------
# 5. Δ-learning target check
# -----------------------------
dE1 = df_phys["E1-CC2"] - df_phys["E1-DFTB"]

print("\n[5] ΔE1 statistics")
print("ΔE1 min / max:", dE1.min(), dE1.max())
print("ΔE1 mean ± std:", dE1.mean(), dE1.std())

# -----------------------------
# 6. Feature matrix integrity
# -----------------------------
X = df_phys[cm_cols].to_numpy(dtype=float)

print("\n[6] Feature matrix check")
print("X shape:", X.shape)
print("X finite:", np.isfinite(X).all())

# -----------------------------
# 7. Correlation sanity (optional but powerful)
# -----------------------------
corr = np.corrcoef(df_phys["E1-DFTB"], df_phys["E1-CC2"])[0, 1]
print("\n[7] Baseline correlation")
print("Corr(E1-DFTB, E1-CC2):", corr)

print("\n===== SANITY CHECK PASSED =====")
# Out:
# ===== DATASET SANITY CHECK =====
#
# [1] Dataset shape
# Rows: 21292
# Columns: 35
#
# [2] Required columns check
# E1-DFTB present: True
# E1-CC2 present : True
# Number of CM features: 26
#
# [3] NaN / Inf check
# NaNs total: 0
# Infs total: 0
#
# [4] Physical range check (Hartree)
# E1-DFTB range: 0.01352 0.84876
# E1-CC2 range: 0.06957 0.51384
#
# [5] ΔE1 statistics
# ΔE1 min / max: -0.62257 0.30557999999999996
# ΔE1 mean ± std: -0.015456138925417997 0.09605807424260773
#
# [6] Feature matrix check
# X shape: (21292, 26)
# X finite: True
#
# [7] Baseline correlation
# Corr(E1-DFTB, E1-CC2): 0.09016857080034928
#
# ===== SANITY CHECK PASSED =====

# %%
DRIVE_OUT = "/content/drive/MyDrive/cleaned_merged_with_CM_5dp.csv"
df_phys.to_csv(DRIVE_OUT, index=False)

print("Saved to Google Drive at:", DRIVE_OUT)
# Out:
# Saved to Google Drive at: /content/drive/MyDrive/cleaned_merged_with_CM_5dp.csv

# %%
import pandas as pd

CSV_PATH = "/content/drive/MyDrive/cleaned_merged_with_CM_5dp.csv"
df = pd.read_csv(CSV_PATH)

# %%
cm_cols = [c for c in df.columns if c.startswith("CM_")]
X = df[cm_cols].to_numpy(dtype=float)

baseline_E1 = df["E1-DFTB"].to_numpy(dtype=float)
target_E1   = df["E1-CC2"].to_numpy(dtype=float)
dE1 = target_E1 - baseline_E1

# %%
print("Rows:", len(df))
print("E1-DFTB range:", df["E1-DFTB"].min(), df["E1-DFTB"].max())
# Out:
# Rows: 21292
# E1-DFTB range: 0.01352 0.84876

# %%
# !pip -q install tensorflow

import numpy as np
import pandas as pd

# %%
CSV_PATH = "/content/drive/MyDrive/cleaned_merged_with_CM_5dp.csv"
df = pd.read_csv(CSV_PATH)

cm_cols = [c for c in df.columns if c.startswith("CM_")]
X = df[cm_cols].to_numpy(dtype=np.float32)

baseline_E1 = df["E1-DFTB"].to_numpy(dtype=np.float32)
target_E1   = df["E1-CC2"].to_numpy(dtype=np.float32)
y = (target_E1 - baseline_E1).astype(np.float32)   # ΔE1

print("X shape:", X.shape)
print("y (ΔE1) mean ± std:", y.mean(), y.std())
print("E1-DFTB range:", baseline_E1.min(), baseline_E1.max())
print("E1-CC2  range:", target_E1.min(), target_E1.max())

assert np.isfinite(X).all()
assert np.isfinite(y).all()
# Out:
# X shape: (21292, 26)
# y (ΔE1) mean ± std: -0.015456138 0.09605582
# E1-DFTB range: 0.01352 0.84876
# E1-CC2  range: 0.06957 0.51384

# %%
from sklearn.model_selection import train_test_split

idx = np.arange(X.shape[0])

idx_train, idx_tmp = train_test_split(idx, test_size=0.30, random_state=42)
idx_val, idx_test  = train_test_split(idx_tmp, test_size=0.50, random_state=42)

X_train, X_val, X_test = X[idx_train], X[idx_val], X[idx_test]
y_train, y_val, y_test = y[idx_train], y[idx_val], y[idx_test]

E1_DFTB_test = baseline_E1[idx_test]
E1_CC2_test  = target_E1[idx_test]

print("Train/Val/Test:", len(idx_train), len(idx_val), len(idx_test))
# Out:
# Train/Val/Test: 14904 3194 3194

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_val_s   = scaler.transform(X_val)
X_test_s  = scaler.transform(X_test)

print("Scaled feature mean (train):", X_train_s.mean().round(4))
print("Scaled feature std  (train):", X_train_s.std().round(4))
# Out:
# Scaled feature mean (train): -0.0
# Scaled feature std  (train): 1.0

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

tf.keras.utils.set_random_seed(42)

model = models.Sequential([
    layers.Input(shape=(X_train_s.shape[1],)),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.10),
    layers.Dense(64, activation="relu"),
    layers.Dropout(0.10),
    layers.Dense(32, activation="relu"),
    layers.Dense(1)   # predicts ΔE1
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="mae",
    metrics=[tf.keras.metrics.RootMeanSquaredError(name="rmse")]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         3,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,825 (54.00 KB)
#  Trainable params: 13,825 (54.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=20,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=8,
        min_lr=1e-6
    )
]

history = model.fit(
    X_train_s, y_train,
    validation_data=(X_val_s, y_val),
    epochs=300,
    batch_size=256,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - loss: 0.1992 - rmse: 0.3025 - val_loss: 0.0630 - val_rmse: 0.0814 - learning_rate: 0.0010
# Epoch 2/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0690 - rmse: 0.0903 - val_loss: 0.0579 - val_rmse: 0.0747 - learning_rate: 0.0010
# Epoch 3/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0624 - rmse: 0.0807 - val_loss: 0.0554 - val_rmse: 0.0713 - learning_rate: 0.0010
# Epoch 4/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0589 - rmse: 0.0758 - val_loss: 0.0545 - val_rmse: 0.0704 - learning_rate: 0.0010
# Epoch 5/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0581 - rmse: 0.0749 - val_loss: 0.0537 - val_rmse: 0.0690 - learning_rate: 0.0010
# Epoch 6/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0563 - rmse: 0.0720 - val_loss: 0.0523 - val_rmse: 0.0675 - learning_rate: 0.0010
# Epoch 7/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0550 - rmse: 0.0710 - val_loss: 0.0525 - val_rmse: 0.0676 - learning_rate: 0.0010
# Epoch 8/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0540 - rmse: 0.0695 - val_loss: 0.0512 - val_rmse: 0.0661 - learning_rate: 0.0010
# Epoch 9/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0532 - rmse: 0.0681 - val_loss: 0.0512 - val_rmse: 0.0662 - learning_rate: 0.0010
# Epoch 10/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0533 - rmse: 0.0684 - val_loss: 0.0504 - val_rmse: 0.0652 - learning_rate: 0.0010
# Epoch 11/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0523 - rmse: 0.0671 - val_loss: 0.0501 - val_rmse: 0.0645 - learning_rate: 0.0010
# Epoch 12/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0517 - rmse: 0.0665 - val_loss: 0.0501 - val_rmse: 0.0645 - learning_rate: 0.0010
# Epoch 13/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0517 - rmse: 0.0662 - val_loss: 0.0499 - val_rmse: 0.0644 - learning_rate: 0.0010
# Epoch 14/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0507 - rmse: 0.0652 - val_loss: 0.0493 - val_rmse: 0.0636 - learning_rate: 0.0010
# Epoch 15/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0505 - rmse: 0.0649 - val_loss: 0.0490 - val_rmse: 0.0631 - learning_rate: 0.0010
# Epoch 16/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0505 - rmse: 0.0647 - val_loss: 0.0487 - val_rmse: 0.0628 - learning_rate: 0.0010
# Epoch 17/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0498 - rmse: 0.0641 - val_loss: 0.0487 - val_rmse: 0.0629 - learning_rate: 0.0010
# Epoch 18/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - rmse: 0.0637 - val_loss: 0.0485 - val_rmse: 0.0625 - learning_rate: 0.0010
# Epoch 19/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - rmse: 0.0630 - val_loss: 0.0483 - val_rmse: 0.0622 - learning_rate: 0.0010
# Epoch 20/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - rmse: 0.0630 - val_loss: 0.0482 - val_rmse: 0.0623 - learning_rate: 0.0010
# Epoch 21/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - rmse: 0.0620 - val_loss: 0.0483 - val_rmse: 0.0622 - learning_rate: 0.0010
# Epoch 22/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - rmse: 0.0619 - val_loss: 0.0478 - val_rmse: 0.0614 - learning_rate: 0.0010
# Epoch 23/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - rmse: 0.0621 - val_loss: 0.0477 - val_rmse: 0.0613 - learning_rate: 0.0010
# Epoch 24/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0481 - rmse: 0.0618 - val_loss: 0.0476 - val_rmse: 0.0612 - learning_rate: 0.0010
# Epoch 25/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0479 - rmse: 0.0613 - val_loss: 0.0477 - val_rmse: 0.0614 - learning_rate: 0.0010
# Epoch 26/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0474 - rmse: 0.0611 - val_loss: 0.0473 - val_rmse: 0.0605 - learning_rate: 0.0010
# Epoch 27/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0477 - rmse: 0.0613 - val_loss: 0.0471 - val_rmse: 0.0606 - learning_rate: 0.0010
# Epoch 28/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0472 - rmse: 0.0605 - val_loss: 0.0469 - val_rmse: 0.0602 - learning_rate: 0.0010
# Epoch 29/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0470 - rmse: 0.0606 - val_loss: 0.0470 - val_rmse: 0.0606 - learning_rate: 0.0010
# Epoch 30/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0464 - rmse: 0.0597 - val_loss: 0.0468 - val_rmse: 0.0605 - learning_rate: 0.0010
# Epoch 31/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0466 - rmse: 0.0600 - val_loss: 0.0468 - val_rmse: 0.0602 - learning_rate: 0.0010
# Epoch 32/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0465 - rmse: 0.0598 - val_loss: 0.0469 - val_rmse: 0.0605 - learning_rate: 0.0010
# Epoch 33/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0467 - rmse: 0.0601 - val_loss: 0.0467 - val_rmse: 0.0603 - learning_rate: 0.0010
# Epoch 34/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0457 - rmse: 0.0590 - val_loss: 0.0465 - val_rmse: 0.0598 - learning_rate: 0.0010
# Epoch 35/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0459 - rmse: 0.0590 - val_loss: 0.0462 - val_rmse: 0.0594 - learning_rate: 0.0010
# Epoch 36/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0457 - rmse: 0.0589 - val_loss: 0.0466 - val_rmse: 0.0598 - learning_rate: 0.0010
# Epoch 37/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0455 - rmse: 0.0587 - val_loss: 0.0463 - val_rmse: 0.0596 - learning_rate: 0.0010
# Epoch 38/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0452 - rmse: 0.0586 - val_loss: 0.0461 - val_rmse: 0.0592 - learning_rate: 0.0010
# Epoch 39/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0455 - rmse: 0.0586 - val_loss: 0.0461 - val_rmse: 0.0592 - learning_rate: 0.0010
# Epoch 40/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0455 - rmse: 0.0586 - val_loss: 0.0463 - val_rmse: 0.0595 - learning_rate: 0.0010
# Epoch 41/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0454 - rmse: 0.0586 - val_loss: 0.0457 - val_rmse: 0.0588 - learning_rate: 0.0010
# Epoch 42/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0452 - rmse: 0.0583 - val_loss: 0.0459 - val_rmse: 0.0590 - learning_rate: 0.0010
# Epoch 43/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0450 - rmse: 0.0578 - val_loss: 0.0461 - val_rmse: 0.0595 - learning_rate: 0.0010
# Epoch 44/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0446 - rmse: 0.0574 - val_loss: 0.0458 - val_rmse: 0.0588 - learning_rate: 0.0010
# Epoch 45/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0446 - rmse: 0.0575 - val_loss: 0.0456 - val_rmse: 0.0586 - learning_rate: 0.0010
# Epoch 46/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0444 - rmse: 0.0573 - val_loss: 0.0454 - val_rmse: 0.0582 - learning_rate: 0.0010
# Epoch 47/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0444 - rmse: 0.0574 - val_loss: 0.0454 - val_rmse: 0.0583 - learning_rate: 0.0010
# Epoch 48/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0441 - rmse: 0.0570 - val_loss: 0.0454 - val_rmse: 0.0582 - learning_rate: 0.0010
# Epoch 49/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0439 - rmse: 0.0568 - val_loss: 0.0456 - val_rmse: 0.0585 - learning_rate: 0.0010
# Epoch 50/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0441 - rmse: 0.0569 - val_loss: 0.0455 - val_rmse: 0.0585 - learning_rate: 0.0010
# Epoch 51/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - rmse: 0.0562 - val_loss: 0.0452 - val_rmse: 0.0579 - learning_rate: 0.0010
# Epoch 52/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - rmse: 0.0565 - val_loss: 0.0452 - val_rmse: 0.0579 - learning_rate: 0.0010
# Epoch 53/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0437 - rmse: 0.0565 - val_loss: 0.0452 - val_rmse: 0.0581 - learning_rate: 0.0010
# Epoch 54/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0435 - rmse: 0.0560 - val_loss: 0.0449 - val_rmse: 0.0575 - learning_rate: 0.0010
# Epoch 55/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0434 - rmse: 0.0563 - val_loss: 0.0452 - val_rmse: 0.0580 - learning_rate: 0.0010
# Epoch 56/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0431 - rmse: 0.0559 - val_loss: 0.0452 - val_rmse: 0.0580 - learning_rate: 0.0010
# Epoch 57/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - rmse: 0.0562 - val_loss: 0.0450 - val_rmse: 0.0580 - learning_rate: 0.0010
# Epoch 58/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432 - rmse: 0.0560 - val_loss: 0.0449 - val_rmse: 0.0578 - learning_rate: 0.0010
# Epoch 59/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0429 - rmse: 0.0556 - val_loss: 0.0448 - val_rmse: 0.0576 - learning_rate: 0.0010
# Epoch 60/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0429 - rmse: 0.0557 - val_loss: 0.0447 - val_rmse: 0.0574 - learning_rate: 0.0010
# Epoch 61/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0427 - rmse: 0.0553 - val_loss: 0.0445 - val_rmse: 0.0571 - learning_rate: 0.0010
# Epoch 62/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0429 - rmse: 0.0555 - val_loss: 0.0446 - val_rmse: 0.0571 - learning_rate: 0.0010
# Epoch 63/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0426 - rmse: 0.0553 - val_loss: 0.0448 - val_rmse: 0.0576 - learning_rate: 0.0010
# Epoch 64/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0428 - rmse: 0.0556 - val_loss: 0.0446 - val_rmse: 0.0576 - learning_rate: 0.0010
# Epoch 65/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0423 - rmse: 0.0547 - val_loss: 0.0446 - val_rmse: 0.0573 - learning_rate: 0.0010
# Epoch 66/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0424 - rmse: 0.0549 - val_loss: 0.0443 - val_rmse: 0.0570 - learning_rate: 0.0010
# Epoch 67/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0421 - rmse: 0.0547 - val_loss: 0.0446 - val_rmse: 0.0571 - learning_rate: 0.0010
# Epoch 68/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0422 - rmse: 0.0548 - val_loss: 0.0441 - val_rmse: 0.0568 - learning_rate: 0.0010
# Epoch 69/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0423 - rmse: 0.0548 - val_loss: 0.0443 - val_rmse: 0.0571 - learning_rate: 0.0010
# Epoch 70/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0419 - rmse: 0.0546 - val_loss: 0.0443 - val_rmse: 0.0568 - learning_rate: 0.0010
# Epoch 71/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0420 - rmse: 0.0546 - val_loss: 0.0443 - val_rmse: 0.0571 - learning_rate: 0.0010
# Epoch 72/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0418 - rmse: 0.0542 - val_loss: 0.0443 - val_rmse: 0.0570 - learning_rate: 0.0010
# Epoch 73/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0417 - rmse: 0.0544 - val_loss: 0.0444 - val_rmse: 0.0569 - learning_rate: 0.0010
# Epoch 74/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0415 - rmse: 0.0537 - val_loss: 0.0440 - val_rmse: 0.0565 - learning_rate: 0.0010
# Epoch 75/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0413 - rmse: 0.0537 - val_loss: 0.0439 - val_rmse: 0.0564 - learning_rate: 0.0010
# Epoch 76/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0416 - rmse: 0.0539 - val_loss: 0.0443 - val_rmse: 0.0569 - learning_rate: 0.0010
# Epoch 77/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0413 - rmse: 0.0537 - val_loss: 0.0444 - val_rmse: 0.0571 - learning_rate: 0.0010
# Epoch 78/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0413 - rmse: 0.0536 - val_loss: 0.0439 - val_rmse: 0.0562 - learning_rate: 0.0010
# Epoch 79/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0413 - rmse: 0.0534 - val_loss: 0.0442 - val_rmse: 0.0567 - learning_rate: 0.0010
# Epoch 80/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0412 - rmse: 0.0537 - val_loss: 0.0439 - val_rmse: 0.0562 - learning_rate: 0.0010
# Epoch 81/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0409 - rmse: 0.0532 - val_loss: 0.0437 - val_rmse: 0.0560 - learning_rate: 0.0010
# Epoch 82/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0412 - rmse: 0.0537 - val_loss: 0.0441 - val_rmse: 0.0568 - learning_rate: 0.0010
# Epoch 83/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0411 - rmse: 0.0535 - val_loss: 0.0440 - val_rmse: 0.0565 - learning_rate: 0.0010
# Epoch 84/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0410 - rmse: 0.0533 - val_loss: 0.0442 - val_rmse: 0.0569 - learning_rate: 0.0010
# Epoch 85/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0406 - rmse: 0.0531 - val_loss: 0.0436 - val_rmse: 0.0561 - learning_rate: 0.0010
# Epoch 86/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0406 - rmse: 0.0529 - val_loss: 0.0436 - val_rmse: 0.0561 - learning_rate: 0.0010
# Epoch 87/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0408 - rmse: 0.0529 - val_loss: 0.0436 - val_rmse: 0.0562 - learning_rate: 0.0010
# Epoch 88/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0406 - rmse: 0.0529 - val_loss: 0.0436 - val_rmse: 0.0561 - learning_rate: 0.0010
# Epoch 89/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0405 - rmse: 0.0529 - val_loss: 0.0439 - val_rmse: 0.0567 - learning_rate: 0.0010
# Epoch 90/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0402 - rmse: 0.0527 - val_loss: 0.0434 - val_rmse: 0.0557 - learning_rate: 5.0000e-04
# Epoch 91/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0400 - rmse: 0.0523 - val_loss: 0.0433 - val_rmse: 0.0557 - learning_rate: 5.0000e-04
# Epoch 92/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0402 - rmse: 0.0522 - val_loss: 0.0432 - val_rmse: 0.0554 - learning_rate: 5.0000e-04
# Epoch 93/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0399 - rmse: 0.0519 - val_loss: 0.0434 - val_rmse: 0.0558 - learning_rate: 5.0000e-04
# Epoch 94/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0399 - rmse: 0.0519 - val_loss: 0.0434 - val_rmse: 0.0558 - learning_rate: 5.0000e-04
# Epoch 95/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0399 - rmse: 0.0521 - val_loss: 0.0433 - val_rmse: 0.0557 - learning_rate: 5.0000e-04
# Epoch 96/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - rmse: 0.0515 - val_loss: 0.0434 - val_rmse: 0.0559 - learning_rate: 5.0000e-04
# Epoch 97/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0394 - rmse: 0.0514 - val_loss: 0.0433 - val_rmse: 0.0556 - learning_rate: 5.0000e-04
# Epoch 98/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - rmse: 0.0517 - val_loss: 0.0432 - val_rmse: 0.0555 - learning_rate: 5.0000e-04
# Epoch 99/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0391 - rmse: 0.0513 - val_loss: 0.0434 - val_rmse: 0.0557 - learning_rate: 5.0000e-04
# Epoch 100/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - rmse: 0.0517 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 2.5000e-04
# Epoch 101/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - rmse: 0.0515 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 2.5000e-04
# Epoch 102/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - rmse: 0.0509 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 2.5000e-04
# Epoch 103/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0387 - rmse: 0.0508 - val_loss: 0.0432 - val_rmse: 0.0555 - learning_rate: 2.5000e-04
# Epoch 104/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - rmse: 0.0513 - val_loss: 0.0433 - val_rmse: 0.0556 - learning_rate: 2.5000e-04
# Epoch 105/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - rmse: 0.0512 - val_loss: 0.0432 - val_rmse: 0.0555 - learning_rate: 2.5000e-04
# Epoch 106/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - rmse: 0.0508 - val_loss: 0.0431 - val_rmse: 0.0553 - learning_rate: 2.5000e-04
# Epoch 107/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0386 - rmse: 0.0506 - val_loss: 0.0431 - val_rmse: 0.0555 - learning_rate: 2.5000e-04
# Epoch 108/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0389 - rmse: 0.0512 - val_loss: 0.0431 - val_rmse: 0.0555 - learning_rate: 2.5000e-04
# Epoch 109/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0386 - rmse: 0.0505 - val_loss: 0.0431 - val_rmse: 0.0552 - learning_rate: 2.5000e-04
# Epoch 110/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0388 - rmse: 0.0508 - val_loss: 0.0432 - val_rmse: 0.0555 - learning_rate: 2.5000e-04
# Epoch 111/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0386 - rmse: 0.0505 - val_loss: 0.0432 - val_rmse: 0.0555 - learning_rate: 2.5000e-04
# Epoch 112/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0387 - rmse: 0.0507 - val_loss: 0.0433 - val_rmse: 0.0556 - learning_rate: 2.5000e-04
# Epoch 113/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0386 - rmse: 0.0506 - val_loss: 0.0432 - val_rmse: 0.0555 - learning_rate: 2.5000e-04
# Epoch 114/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0386 - rmse: 0.0509 - val_loss: 0.0431 - val_rmse: 0.0554 - learning_rate: 2.5000e-04
# Epoch 115/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - rmse: 0.0502 - val_loss: 0.0431 - val_rmse: 0.0555 - learning_rate: 1.2500e-04
# Epoch 116/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0383 - rmse: 0.0505 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 1.2500e-04
# Epoch 117/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0386 - rmse: 0.0506 - val_loss: 0.0432 - val_rmse: 0.0557 - learning_rate: 1.2500e-04
# Epoch 118/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0383 - rmse: 0.0504 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 1.2500e-04
# Epoch 119/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0387 - rmse: 0.0507 - val_loss: 0.0432 - val_rmse: 0.0557 - learning_rate: 1.2500e-04
# Epoch 120/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0384 - rmse: 0.0503 - val_loss: 0.0433 - val_rmse: 0.0557 - learning_rate: 1.2500e-04
# Epoch 121/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384 - rmse: 0.0502 - val_loss: 0.0432 - val_rmse: 0.0557 - learning_rate: 1.2500e-04
# Epoch 122/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0383 - rmse: 0.0501 - val_loss: 0.0433 - val_rmse: 0.0557 - learning_rate: 1.2500e-04
# Epoch 123/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - rmse: 0.0505 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 6.2500e-05
# Epoch 124/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0385 - rmse: 0.0505 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 6.2500e-05
# Epoch 125/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0383 - rmse: 0.0503 - val_loss: 0.0432 - val_rmse: 0.0557 - learning_rate: 6.2500e-05
# Epoch 126/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0382 - rmse: 0.0499 - val_loss: 0.0432 - val_rmse: 0.0557 - learning_rate: 6.2500e-05
# Epoch 127/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0382 - rmse: 0.0501 - val_loss: 0.0432 - val_rmse: 0.0557 - learning_rate: 6.2500e-05
# Epoch 128/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0386 - rmse: 0.0508 - val_loss: 0.0433 - val_rmse: 0.0558 - learning_rate: 6.2500e-05
# Epoch 129/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0387 - rmse: 0.0507 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 6.2500e-05
# Epoch 130/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0382 - rmse: 0.0502 - val_loss: 0.0432 - val_rmse: 0.0557 - learning_rate: 6.2500e-05
# Epoch 131/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - rmse: 0.0505 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 3.1250e-05
# Epoch 132/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0385 - rmse: 0.0506 - val_loss: 0.0432 - val_rmse: 0.0556 - learning_rate: 3.1250e-05
# Epoch 133/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0384 - rmse: 0.0505 - val_loss: 0.0431 - val_rmse: 0.0556 - learning_rate: 3.1250e-05
# Epoch 134/300
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0385 - rmse: 0.0502 - val_loss: 0.0431 - val_rmse: 0.0556 - learning_rate: 3.1250e-05

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Predict ΔE1
dE_pred = model.predict(X_test_s, verbose=0).reshape(-1)

# Corrected excitation energy
E1_pred = E1_DFTB_test + dE_pred

# Baseline metrics
mae_base  = mean_absolute_error(E1_CC2_test, E1_DFTB_test)
rmse_base = np.sqrt(mean_squared_error(E1_CC2_test, E1_DFTB_test))

# Corrected metrics
mae_corr  = mean_absolute_error(E1_CC2_test, E1_pred)
rmse_corr = np.sqrt(mean_squared_error(E1_CC2_test, E1_pred))
r2_corr   = r2_score(E1_CC2_test, E1_pred)

print("Baseline MAE (DFTB → CC2):", mae_base)
print("Corrected MAE (DFTB + Δ → CC2):", mae_corr)
print("Baseline RMSE:", rmse_base)
print("Corrected RMSE:", rmse_corr)
print("R² (corrected):", r2_corr)
print("MAE improvement factor:", mae_base / mae_corr)
# Out:
# Baseline MAE (DFTB → CC2): 0.07434999942779541
# Corrected MAE (DFTB + Δ → CC2): 0.04172660782933235
# Baseline RMSE: 0.09703889737576989
# Corrected RMSE: 0.05344146842749379
# R² (corrected): -0.5310747623443604
# MAE improvement factor: 1.781836657604598

# %%
abs_err = np.abs(E1_CC2_test - E1_pred)

print("P50 AE (median):", np.percentile(abs_err, 50))
print("P90 AE:", np.percentile(abs_err, 90))
print("P95 AE:", np.percentile(abs_err, 95))
print("Max AE:", abs_err.max())
# Out:
# P50 AE (median): 0.03397943
# P90 AE: 0.088039145
# P95 AE: 0.10634223
# Max AE: 0.23748454

# %%
import pandas as pd

comparison_df = pd.DataFrame([
    # ---------------- PAPER RESULTS ----------------
    {
        "Source": "Ramakrishnan et al. (JCTC 2015)",
        "Baseline": "TDDFT",
        "ML model": "Kernel Ridge (Laplacian)",
        "Descriptor": "Coulomb Matrix",
        "Training size": "5k",
        "MAE (eV)": 0.13,
        "RMSE (eV)": None,
        "P50 AE (eV)": None,
        "P90 AE (eV)": None,
        "P95 AE (eV)": None,
        "Max AE (eV)": None,
    },
    {
        "Source": "Ramakrishnan et al. (JCTC 2015)",
        "Baseline": "TDDFT",
        "ML model": "Kernel Ridge (Laplacian)",
        "Descriptor": "Bag of Bonds",
        "Training size": "5k",
        "MAE (eV)": 0.09,
        "RMSE (eV)": None,
        "P50 AE (eV)": None,
        "P90 AE (eV)": None,
        "P95 AE (eV)": None,
        "Max AE (eV)": None,
    },

    # ---------------- YOUR BASELINE ----------------
    {
        "Source": "This work",
        "Baseline": "DFTB",
        "ML model": "None (baseline)",
        "Descriptor": "—",
        "Training size": "—",
        "MAE (eV)": mae_base,
        "RMSE (eV)": rmse_base,
        "P50 AE (eV)": np.percentile(np.abs(E1_CC2_test - E1_DFTB_test), 50),
        "P90 AE (eV)": np.percentile(np.abs(E1_CC2_test - E1_DFTB_test), 90),
        "P95 AE (eV)": np.percentile(np.abs(E1_CC2_test - E1_DFTB_test), 95),
        "Max AE (eV)": np.abs(E1_CC2_test - E1_DFTB_test).max(),
    },

    # ---------------- YOUR ML RESULT ----------------
    {
        "Source": "This work",
        "Baseline": "DFTB",
        "ML model": "Neural Network (Δ-learning)",
        "Descriptor": "Reduced Coulomb Matrix",
        "Training size": "15k+",
        "MAE (eV)": mae_corr,
        "RMSE (eV)": rmse_corr,
        "P50 AE (eV)": np.percentile(abs_err, 50),
        "P90 AE (eV)": np.percentile(abs_err, 90),
        "P95 AE (eV)": np.percentile(abs_err, 95),
        "Max AE (eV)": abs_err.max(),
    }
])

comparison_df
# Out:
#                             Source Baseline                     ML model  \
# 0  Ramakrishnan et al. (JCTC 2015)    TDDFT     Kernel Ridge (Laplacian)
# 1  Ramakrishnan et al. (JCTC 2015)    TDDFT     Kernel Ridge (Laplacian)
# 2                        This work     DFTB              None (baseline)
# 3                        This work     DFTB  Neural Network (Δ-learning)
#
#                Descriptor Training size  MAE (eV)  RMSE (eV)  P50 AE (eV)  \
# 0          Coulomb Matrix            5k  0.130000        NaN          NaN
# 1            Bag of Bonds            5k  0.090000        NaN          NaN
# 2                       —             —  0.074350   0.097039     0.061100
# 3  Reduced Coulomb Matrix          15k+  0.041727   0.053441     0.033979
#
#    P90 AE (eV)  P95 AE (eV)  Max AE (eV)
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2     0.161387     0.202843     0.367750
# 3     0.088039     0.106342     0.237485
